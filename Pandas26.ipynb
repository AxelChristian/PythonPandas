# %% [markdown]
# # PANDAS26 Membuat Data Frame dari hasil seleksi Spreadsheet

# %% [markdown]
# ## Import modules & cek versi

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.2.3

# %% [markdown]
# ## Membuat Data Frame dari hasil seleksi Spreadsheet

# %% [markdown]
# - membaca hasil copy dari file spreadsheet (excel/sheets)
# - baris pertama akan selalu menjadi judul tabel

# %%
df = pd.read_clipboard()
df
# Out:
#    ID_barang           nama   jenis barang  harga_modal  harga_jual ukuran  \
# 0       5024  Metrolite 001     Cat tembok       110000      135000      5
# 1       5126    Kikir bahco    Alat tukang        30000       40000      4
# 2       5178  Kunci roofing    Alat tukang         4500       10000      8
# 3       5367        Quantum  Regulator gas        50000       65000      -
# 4       5210        Triplek        meranti        45000       55000      3
# 5       5025     Paku asbes           Paku        25000       35000      5
# 6       5060   Baud Gangsol           baut         1000        6000      6
# 7       5006      Tiga roda    semen putih        75000       97500     40
# 8       5007    siku lubang           besi        72500       95000      3
# 9       5004      kawat Las          kawat        22500       25000      2
#
#   jenis_ukuran jenis_satuan  jumlah_barang  pemilik.Id_pemilik  ID_supplier
# ...
